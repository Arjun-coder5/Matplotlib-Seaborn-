# %% [markdown]
# <a href="https://colab.research.google.com/github/Arjun-coder5/Matplotlib-Seaborn-/blob/main/MatplotLib_and_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Start of Matplotlib and seaborn :
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Matplotlib Basics :

# %%
from logging import log
x = np.linspace(0,5,11)
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title("Arjun")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.plot(x,y)
plt.title("Hey")
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.show()
